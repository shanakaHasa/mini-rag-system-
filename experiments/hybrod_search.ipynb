# %%
import pandas as pd

dataset = pd.read_csv("../data/wiki_movie_plots_deduped.csv")
dataset.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
df = dataset[["Title", "Plot"]]
df.head()
# Out:
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
df = df[:500]
df.describe()
# Out:
#                           Title  \
# count                       500
# unique                      488
# top     Dr. Jekyll and Mr. Hyde
# freq                          3
#
#                                                      Plot
# count                                                 500
# unique                                                497
# top     As described in a film magazine,[1] Jules Lene...
# freq                                                    2

# %%
df.isnull().sum()
# Out:
# Title    0
# Plot     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df = df.drop_duplicates()

# %%
df['Title'] = df['Title'].astype(str)
df['Plot'] = df['Plot'].astype(str)

# %%
df.head()
# Out:
#                               Title  \
# 0            Kansas Saloon Smashers
# 1     Love by the Light of the Moon
# 2           The Martyred Presidents
# 3  Terrible Teddy, the Grizzly King
# 4            Jack and the Beanstalk
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
def chunk_text_with_overlap(text, chunk_size=300, overlap=60):
    words = text.split()
    chunks = []

    start = 0
    while start < len(words):
        end = start + chunk_size
        chunk = " ".join(words[start:end])
        chunks.append(chunk)

        start += (chunk_size - overlap)

    return chunks

# %%
documents = []

for idx, row in df.iterrows():
    title = row["Title"]
    plot = row["Plot"]

    chunks = chunk_text_with_overlap(plot, chunk_size=300, overlap=60)

    for chunk_id, chunk in enumerate(chunks):
        documents.append({
            "id": f"{idx}_{chunk_id}",
            "title": title,
            "text": chunk
        })
documents_df = pd.DataFrame(documents)
documents_df.head()
# Out:
#     id                             title  \
# 0  0_0            Kansas Saloon Smashers
# 1  1_0     Love by the Light of the Moon
# 2  2_0           The Martyred Presidents
# 3  3_0  Terrible Teddy, the Grizzly King
# 4  4_0            Jack and the Beanstalk
#
#                                                 text
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
documents[:3]
# Out:
# [{'id': '0_0',
#   'title': 'Kansas Saloon Smashers',
#   'text': "A bartender is working at a saloon, serving drinks to customers. After he fills a stereotypically Irish man's bucket with beer, Carrie Nation and her followers burst inside. They assault the Irish man, pulling his hat over his eyes and then dumping the beer over his head. The group then begin wrecking the bar, smashing the fixtures, mirrors, and breaking the cash register. The bartender then sprays seltzer water in Nation's face before a group of policemen appear and order everybody to leave.[1]"},
#  {'id': '1_0',
#   'title': 'Love by the Light of the Moon',
#   'text': "The moon, painted with a smiling face hangs over a park at night. A young couple walking past a fence learn on a railing and look up. The moon smiles. They embrace, and the moon's smile gets bigger. They then sit down on a bench by a tree. The moon's view is blocked, causing him to frown. In the last scene, the man fans the woman with his hat because the moon has left the sky and is perched over her shoulder to see everything better."},
#  {'id': '2_0',
#   'title': 'The Martyred Presidents',
#   'text': 'The film, just over a minute long, is composed of two shots. In the first, a girl sits at the base of an altar or tomb, her face hidden from the camera. At the center of the altar, a viewing portal displays the portraits of three U.S. Presidents—Abraham Lincoln, James A. Garfield, and William McKinley—each victims of assassination. In the second shot, which runs just over eight seconds long, an assassin kneels feet of Lady Justice.'}]

# %%
#checking chunk overlap is working
long_text = "word " * 800  
chunks = chunk_text_with_overlap(long_text, 300, 60)

for i, chunk in enumerate(chunks):
    print(i, len(chunk.split()))
# Out:
# 0 300
# 1 300
# 2 300
# 3 80

# %%
chunk0_end = chunks[0].split()[-60:]
chunk1_start = chunks[1].split()[:60]

print(chunk0_end == chunk1_start)
# Out:
# True

# %%
# !pip install chromadb sentence-transformers
# Out:
# Requirement already satisfied: chromadb in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (1.1.1)
# Requirement already satisfied: sentence-transformers in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (5.1.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (2.12.2)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.37.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (2.3.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.23.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\hasaranga\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\hasaranga\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.10.5)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: scikit-learn in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (0.35.3)
# Requirement already satisfied: Pillow in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: filelock in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.23)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: pyproject_hooks in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\hasaranga\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.0->chromadb) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.41.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.11.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hasaranga\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install tf-keras
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hasaranga\appdata\roaming\python\python313\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: pillow in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hasaranga\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hasaranga\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.5 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.2 MB/s  0:00:01
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.20.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
import chromadb
# Out:
# WARNING:tensorflow:From c:\Users\Hasaranga\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

#Chroma db client initialization
client = chromadb.Client()

#create collection
collection = client.create_collection(name="movie_plots")

for doc in documents:
    embedding = model.encode(doc['text']).tolist()
    collection.add(
        documents=[doc['text']],
        metadatas=[{"id": doc['id'], "title": doc['title']}],
        ids=[doc['id']],
        embeddings=[embedding]
    )
# Out:
# c:\Users\Hasaranga\AppData\Local\Programs\Python\Python313\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Hasaranga\.cache\huggingface\hub\models--sentence-transformers--all-mpnet-base-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %%
import chromadb
from sentence_transformers import SentenceTransformer

# Initialize embedding model
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# Use PersistentClient instead of in-memory client
client = chromadb.PersistentClient(path="../chroma_db")  # "chroma_db" is the folder to save

# %%
# If you want to create a new collection:
collection = client.create_collection(name="movie_plots")

# %%
for doc in documents:  # documents = your chunked list of dicts
    embedding = model.encode(doc['text']).tolist()
    collection.add(
        documents=[doc['text']],
        metadatas=[{"id": doc['id'], "title": doc['title']}],
        ids=[doc['id']],
        embeddings=[embedding]
    )

# %%
client = chromadb.PersistentClient(path="chroma_db")
collection = client.get_collection(name="movie_plots")

# %%
query = "A movie about a robot that becomes human"
query_embedding = model.encode(query).tolist()

#hybrid search (vector + metadata filter)
results = collection.query(
    query_embeddings=[query_embedding],
    n_results=5,
    where={"title": {"$eq": "Love by the Light of the Moon"}}  
)

print(results)
# Out:
# {'ids': [['1_0']], 'embeddings': None, 'documents': [["The moon, painted with a smiling face hangs over a park at night. A young couple walking past a fence learn on a railing and look up. The moon smiles. They embrace, and the moon's smile gets bigger. They then sit down on a bench by a tree. The moon's view is blocked, causing him to frown. In the last scene, the man fans the woman with his hat because the moon has left the sky and is perched over her shoulder to see everything better."]], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[{'id': '1_0', 'title': 'Love by the Light of the Moon'}]], 'distances': [[1.6285232305526733]]}
